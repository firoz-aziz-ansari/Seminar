# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Code inspired by: https://github.com/sorenbouma/keras-oneshot/

# %% [markdown]
# # Preprocessing the dataset

# %%
import numpy as np
from scipy.misc import imread
import pickle
import os

# %%
"""Script to preprocess the omniglot dataset and pickle it into an array that's easy to index by character type"""

data_path = '/content/gdrive/My Drive/Colab Notebooks/Omniglot_all/'
train_path = os.path.join(data_path, "images_background")
test_path = os.path.join(data_path,"images_evaluation")

lang_dict = {}

def loadimgs(path, n=0):
    X=[]
    y = []
    cat_dict = {}
    lang_dict = {}
    curr_y = n
    # we load every alphabet separately so we can isolate them later
    for alphabet in os.listdir(path):
        print("loading alphabet: " + alphabet)
        lang_dict[alphabet] = [curr_y,None]
        alphabet_path = os.path.join(path,alphabet)
        # every letter/category has its own column in the array, so load separately
        for letter in os.listdir(alphabet_path):
            cat_dict[curr_y] = (alphabet, letter)
            category_images=[]
            letter_path = os.path.join(alphabet_path, letter)
            for filename in os.listdir(letter_path):
                image_path = os.path.join(letter_path, filename)
                image = imread(image_path)
                category_images.append(image)
                y.append(curr_y)
            try:
                X.append(np.stack(category_images))
            #edge case  - last one
            except ValueError as e:
                print(e)
                print("error - category_images:", category_images)
            curr_y += 1
            lang_dict[alphabet][1] = curr_y - 1
    y = np.vstack(y)
    X = np.stack(X)
    return X, y, lang_dict

X, y, c = loadimgs(train_path)
with open(os.path.join(data_path, "pickle_files/omniglot_train.p"), "wb") as f:
    pickle.dump((X, c), f)

X, y, c = loadimgs(test_path)
with open(os.path.join(data_path, "pickle_files/omniglot_test.p"), "wb") as f:
    pickle.dump((X, c), f)
# Out:
# loading alphabet: Arcadian
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# loading alphabet: Burmese_(Myanmar)
# loading alphabet: Balinese
# loading alphabet: Blackfoot_(Canadian_Aboriginal_Syllabics)
# loading alphabet: Braille
# loading alphabet: Armenian
# loading alphabet: Anglo-Saxon_Futhorc
# loading alphabet: Alphabet_of_the_Magi
# loading alphabet: Asomtavruli_(Georgian)
# loading alphabet: Bengali
# loading alphabet: Hebrew
# loading alphabet: Japanese_(katakana)
# loading alphabet: Gujarati
# loading alphabet: Grantha
# loading alphabet: Futurama
# loading alphabet: Inuktitut_(Canadian_Aboriginal_Syllabics)
# loading alphabet: Japanese_(hiragana)
# loading alphabet: Early_Aramaic
# loading alphabet: Greek
# loading alphabet: Cyrillic
# loading alphabet: Malay_(Jawi_-_Arabic)
# loading alphabet: N_Ko
# loading alphabet: Tagalog
# loading alphabet: Latin
# loading alphabet: Tifinagh
# loading alphabet: Syriac_(Estrangelo)
# loading alphabet: Korean
# loading alphabet: Mkhedruli_(Georgian)
# loading alphabet: Sanskrit
# loading alphabet: Ojibwe_(Canadian_Aboriginal_Syllabics)
# loading alphabet: Keble
# loading alphabet: Atlantean
# loading alphabet: Angelic
# loading alphabet: Avesta
# loading alphabet: Ge_ez
# loading alphabet: Atemayar_Qelisayer
# loading alphabet: Aurek-Besh
# loading alphabet: Kannada
# loading alphabet: Gurmukhi
# loading alphabet: Glagolitic
# loading alphabet: Tibetan
# loading alphabet: Mongolian
# loading alphabet: Malayalam
# loading alphabet: Manipuri
# loading alphabet: Oriya
# loading alphabet: Tengwar
# loading alphabet: Sylheti
# loading alphabet: Syriac_(Serto)
# loading alphabet: ULOG
# loading alphabet: Old_Church_Slavonic_(Cyrillic)

# %%
PATH = '/content/gdrive/My Drive/Colab Notebooks/Omniglot_all/pickle_files/'

with open(os.path.join(PATH, "omniglot_train.p"), "rb") as f:
    (X_train, c_train) = pickle.load(f)

with open(os.path.join(PATH, "omniglot_test.p"), "rb") as f:
    (X_test, c_test) = pickle.load(f)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("")
print("training alphabets")
print([key for key in c_train.keys()])
print("test alphabets:")
print([key for key in c_test.keys()])
# Out:
# X_train shape: (964, 20, 105, 105)
# X_test shape: (659, 20, 105, 105)
#
# training alphabets
# ['Arcadian', 'Burmese_(Myanmar)', 'Balinese', 'Blackfoot_(Canadian_Aboriginal_Syllabics)', 'Braille', 'Armenian', 'Anglo-Saxon_Futhorc', 'Alphabet_of_the_Magi', 'Asomtavruli_(Georgian)', 'Bengali', 'Hebrew', 'Japanese_(katakana)', 'Gujarati', 'Grantha', 'Futurama', 'Inuktitut_(Canadian_Aboriginal_Syllabics)', 'Japanese_(hiragana)', 'Early_Aramaic', 'Greek', 'Cyrillic', 'Malay_(Jawi_-_Arabic)', 'N_Ko', 'Tagalog', 'Latin', 'Tifinagh', 'Syriac_(Estrangelo)', 'Korean', 'Mkhedruli_(Georgian)', 'Sanskrit', 'Ojibwe_(Canadian_Aboriginal_Syllabics)']
# test alphabets:
# ['Keble', 'Atlantean', 'Angelic', 'Avesta', 'Ge_ez', 'Atemayar_Qelisayer', 'Aurek-Besh', 'Kannada', 'Gurmukhi', 'Glagolitic', 'Tibetan', 'Mongolian', 'Malayalam', 'Manipuri', 'Oriya', 'Tengwar', 'Sylheti', 'Syriac_(Serto)', 'ULOG', 'Old_Church_Slavonic_(Cyrillic)']

# %% [markdown]
# # Siamese Network with L2 distance

# %%
from keras.layers import Input, Conv2D, Lambda, Dense, Flatten, MaxPooling2D, Dropout, BatchNormalization
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.losses import binary_crossentropy
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

input_shape = (105, 105, 1)
left_input = Input(input_shape)
right_input = Input(input_shape)

# build convnet to use in each siamese 'leg'
convnet = Sequential()
convnet.add(Conv2D(64, (10,10), activation='relu', input_shape=input_shape, kernel_regularizer=l2(2e-4)))
convnet.add(MaxPooling2D())
convnet.add(BatchNormalization())
convnet.add(Dropout(0.25))
convnet.add(Conv2D(128, (7,7), activation='relu', kernel_regularizer=l2(2e-4)))
convnet.add(MaxPooling2D())
convnet.add(BatchNormalization())
convnet.add(Dropout(0.25))
convnet.add(Conv2D(128, (4,4), activation='relu', kernel_regularizer=l2(2e-4)))
convnet.add(MaxPooling2D())
convnet.add(BatchNormalization())
convnet.add(Dropout(0.25))
convnet.add(Conv2D(256, (4,4), activation='relu', kernel_regularizer=l2(2e-4)))
convnet.add(Flatten())
convnet.add(BatchNormalization())
convnet.add(Dropout(0.25))
convnet.add(Dense(4096, activation="sigmoid", kernel_regularizer=l2(1e-3)))
convnet.summary()

# encode each of the two inputs into a vector with the convnet
encoded_l = convnet(left_input)
encoded_r = convnet(right_input)

# merge two encoded inputs with the L1 distance between them, and connect to prediction output layer
L1_distance = lambda x: K.abs(x[0]-x[1])
both = Lambda(L1_distance)([encoded_l, encoded_r])
prediction = Dense(1, activation='sigmoid')(both)
siamese_net = Model(inputs=[left_input,right_input], outputs=prediction)


siamese_net.compile(loss="binary_crossentropy", optimizer="adam")

siamese_net.summary()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 96, 96, 64)        6464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 42, 42, 128)       401536
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 21, 21, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 21, 21, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 21, 21, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 128)       262272
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 128)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9, 9, 128)         512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9, 9, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 256)         524544
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 9216)              36864
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 9216)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              37752832
# =================================================================
# Total params: 38,985,792
# Trainable params: 38,966,720
# Non-trainable params: 19,072
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 105, 105, 1)  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 105, 105, 1)  0
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 4096)         38985792    input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4096)         0           sequential_1[1][0]
#                                                                  sequential_1[2][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            4097        lambda_1[0][0]
# ==================================================================================================
# Total params: 38,989,889
# Trainable params: 38,970,817
# Non-trainable params: 19,072
# __________________________________________________________________________________________________

# %%
def get_batch(batch_size, X):
    """Create batch of n pairs, half same class, half different class"""
    n_classes, n_examples, w, h = X.shape
    # randomly sample several classes to use in the batch
    categories = np.random.choice(n_classes, size=(batch_size,), replace=False)
    # initialize 2 empty arrays for the input image batch
    pairs = [np.zeros((batch_size, h, w, 1)) for i in range(2)]
    # initialize vector for the targets, and make one half of it '1's, so 2nd half of batch has same class
    targets = np.zeros((batch_size,))
    targets[batch_size//2:] = 1
    for i in range(batch_size):
        category = categories[i]
        idx_1 = np.random.randint(0, n_examples)
        pairs[0][i, :, :, :] = X[category, idx_1].reshape(w, h, 1)
        idx_2 = np.random.randint(0, n_examples)
        # pick images of same class for 1st half, different for 2nd
        if i >= batch_size // 2:
            category_2 = category
        else:
            #add a random number to the category modulo n_classes to ensure 2nd image has different category
            category_2 = (category + np.random.randint(1,n_classes)) % n_classes
        pairs[1][i, :, :, :] = X[category_2,idx_2].reshape(w, h, 1)
    return pairs, targets

def batch_generator(batch_size, X):
    """a generator for batches, so model.fit_generator can be used. """
    while True:
        pairs, targets = get_batch(batch_size, X)
        yield (pairs, targets)

def train(model, X_train, batch_size=64, steps_per_epoch=100, epochs=1):
    model.fit_generator(batch_generator(batch_size, X_train), steps_per_epoch=steps_per_epoch, epochs=epochs)

# %%
def make_oneshot_task(N, X, c, language=None):
    """Create pairs of (test image, support set image) with ground truth, for testing N-way one-shot learning."""
    n_classes, n_examples, w, h = X.shape
    indices = np.random.randint(0, n_examples, size=(N,))
    if language is not None:
        low, high = c[language]
        if N > high - low:
            raise ValueError("This language ({}) has less than {} letters".format(language, N))
        categories = np.random.choice(range(low,high), size=(N,), replace=False)
    else:  # if no language specified just pick a bunch of random letters
        categories = np.random.choice(range(n_classes), size=(N,), replace=False)            
    true_category = categories[0]
    ex1, ex2 = np.random.choice(n_examples, replace=False, size=(2,))
    test_image = np.asarray([X[true_category, ex1, :, :]]*N).reshape(N, w, h, 1)
    support_set = X[categories, indices, :, :]
    support_set[0, :, :] = X[true_category, ex2]
    support_set = support_set.reshape(N, w, h, 1)
    targets = np.zeros((N,))
    targets[0] = 1
    targets, test_image, support_set = shuffle(targets, test_image, support_set)
    pairs = [test_image, support_set]
    return pairs, targets

def test_oneshot(model, X, c, N=20, k=250, language=None, verbose=True):
    """Test average N-way oneshot learning accuracy of a siamese neural net over k one-shot tasks."""
    n_correct = 0
    if verbose:
        print("Evaluating model on {} random {}-way one-shot learning tasks ...".format(k, N))
    for i in range(k):
        inputs, targets = make_oneshot_task(N, X, c, language=language)
        probs = model.predict(inputs)
        if np.argmax(probs) == np.argmax(targets):
            n_correct += 1
    percent_correct = (100.0*n_correct / k)
    if verbose:
        print("Got an average of {}% accuracy for {}-way one-shot learning".format(percent_correct, N))
    return percent_correct

# %%
loops = 200
best_acc = 0
for i in range(loops):
    print("=== Training loop {} ===".format(i+1))
    train(siamese_net, X_train)
    test_acc = test_oneshot(siamese_net, X_test, c_test)
    if test_acc >= best_acc:
        print("New best one-shot accuracy, saving model ...")
        siamese_net.save("/content/gdrive/My Drive/Colab Notebooks/Omniglot_all/siamese_omniglot.h5")
        best_acc = test_acc
# Out:
# === Training loop 1 ===
# Epoch 1/1
# 100/100 [==============================] - 36s 358ms/step - loss: 4.2937
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 15.6% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 2 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 1.9795
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.8% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 3 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 1.3448
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 42.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 4 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 1.2068
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 34.0% accuracy for 20-way one-shot learning
# === Training loop 5 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.2369
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 42.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 6 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 1.2259
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 40.8% accuracy for 20-way one-shot learning
# === Training loop 7 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 1.2704
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 40.0% accuracy for 20-way one-shot learning
# === Training loop 8 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 1.2866
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 29.2% accuracy for 20-way one-shot learning
# === Training loop 9 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.2933
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 48.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 10 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.2874
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 44.8% accuracy for 20-way one-shot learning
# === Training loop 11 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.3077
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 48.8% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 12 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.3013
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 45.2% accuracy for 20-way one-shot learning
# === Training loop 13 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.3454
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 50.8% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 14 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 1.3456
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 54.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 15 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.3238
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 51.2% accuracy for 20-way one-shot learning
# === Training loop 16 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.3303
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 48.4% accuracy for 20-way one-shot learning
# === Training loop 17 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 1.3300
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 54.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 18 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 1.3269
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 53.2% accuracy for 20-way one-shot learning
# === Training loop 19 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.2842
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 53.6% accuracy for 20-way one-shot learning
# === Training loop 20 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.3021
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 44.8% accuracy for 20-way one-shot learning
# === Training loop 21 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.3485
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 54.4% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 22 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 1.2881
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 51.6% accuracy for 20-way one-shot learning
# === Training loop 23 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.3348
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 53.2% accuracy for 20-way one-shot learning
# === Training loop 24 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.3370
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 57.2% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 25 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.3426
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 57.2% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 26 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 1.3246
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 64.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 27 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.2833
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 50.0% accuracy for 20-way one-shot learning
# === Training loop 28 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.2736
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 62.0% accuracy for 20-way one-shot learning
# === Training loop 29 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.2578
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 49.6% accuracy for 20-way one-shot learning
# === Training loop 30 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 1.2323
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 21.2% accuracy for 20-way one-shot learning
# === Training loop 31 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 1.2167
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 53.6% accuracy for 20-way one-shot learning
# === Training loop 32 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.2157
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 33.6% accuracy for 20-way one-shot learning
# === Training loop 33 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.1490
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 44.8% accuracy for 20-way one-shot learning
# === Training loop 34 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.1600
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 63.6% accuracy for 20-way one-shot learning
# === Training loop 35 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.1595
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 62.0% accuracy for 20-way one-shot learning
# === Training loop 36 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.2074
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 61.2% accuracy for 20-way one-shot learning
# === Training loop 37 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 1.1784
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 23.2% accuracy for 20-way one-shot learning
# === Training loop 38 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.1849
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 63.2% accuracy for 20-way one-shot learning
# === Training loop 39 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.1319
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 58.8% accuracy for 20-way one-shot learning
# === Training loop 40 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 301ms/step - loss: 1.0963
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 61.6% accuracy for 20-way one-shot learning
# === Training loop 41 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.1211
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 51.6% accuracy for 20-way one-shot learning
# === Training loop 42 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.1048
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 60.8% accuracy for 20-way one-shot learning
# === Training loop 43 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.1318
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 34.4% accuracy for 20-way one-shot learning
# === Training loop 44 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.1398
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 56.0% accuracy for 20-way one-shot learning
# === Training loop 45 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.0923
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 9.2% accuracy for 20-way one-shot learning
# === Training loop 46 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.1134
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 17.2% accuracy for 20-way one-shot learning
# === Training loop 47 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.1250
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 58.8% accuracy for 20-way one-shot learning
# === Training loop 48 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.0885
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 60.8% accuracy for 20-way one-shot learning
# === Training loop 49 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 1.0422
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 70.8% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 50 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 1.0248
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 57.6% accuracy for 20-way one-shot learning
# === Training loop 51 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.0148
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 59.6% accuracy for 20-way one-shot learning
# === Training loop 52 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 1.0758
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 34.4% accuracy for 20-way one-shot learning
# === Training loop 53 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 1.0344
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 69.2% accuracy for 20-way one-shot learning
# === Training loop 54 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 1.0051
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 65.2% accuracy for 20-way one-shot learning
# === Training loop 55 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.9954
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 61.6% accuracy for 20-way one-shot learning
# === Training loop 56 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.9463
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 73.6% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 57 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 1.0009
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 51.6% accuracy for 20-way one-shot learning
# === Training loop 58 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 301ms/step - loss: 0.9974
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 70.8% accuracy for 20-way one-shot learning
# === Training loop 59 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.9528
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 58.0% accuracy for 20-way one-shot learning
# === Training loop 60 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 301ms/step - loss: 0.9447
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 66.4% accuracy for 20-way one-shot learning
# === Training loop 61 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.9691
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 66.0% accuracy for 20-way one-shot learning
# === Training loop 62 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 301ms/step - loss: 0.9862
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 55.6% accuracy for 20-way one-shot learning
# === Training loop 63 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.9295
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 56.0% accuracy for 20-way one-shot learning
# === Training loop 64 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.8796
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 61.6% accuracy for 20-way one-shot learning
# === Training loop 65 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.8340
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 67.2% accuracy for 20-way one-shot learning
# === Training loop 66 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.8566
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 69.6% accuracy for 20-way one-shot learning
# === Training loop 67 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.8208
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 56.8% accuracy for 20-way one-shot learning
# === Training loop 68 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.8293
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.4% accuracy for 20-way one-shot learning
# === Training loop 69 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.8652
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 66.0% accuracy for 20-way one-shot learning
# === Training loop 70 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.8716
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 70.0% accuracy for 20-way one-shot learning
# === Training loop 71 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.8699
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 50.4% accuracy for 20-way one-shot learning
# === Training loop 72 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.8939
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 74.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 73 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 0.8323
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 69.6% accuracy for 20-way one-shot learning
# === Training loop 74 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.8123
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 52.8% accuracy for 20-way one-shot learning
# === Training loop 75 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.7907
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 34.8% accuracy for 20-way one-shot learning
# === Training loop 76 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.8021
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 38.0% accuracy for 20-way one-shot learning
# === Training loop 77 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.8145
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 69.2% accuracy for 20-way one-shot learning
# === Training loop 78 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.8406
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 55.2% accuracy for 20-way one-shot learning
# === Training loop 79 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 301ms/step - loss: 0.8514
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 34.4% accuracy for 20-way one-shot learning
# === Training loop 80 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.8564
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 56.4% accuracy for 20-way one-shot learning
# === Training loop 81 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.8037
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.8% accuracy for 20-way one-shot learning
# === Training loop 82 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.7643
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.4% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 83 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.7447
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 62.0% accuracy for 20-way one-shot learning
# === Training loop 84 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.7830
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 67.2% accuracy for 20-way one-shot learning
# === Training loop 85 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.7733
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 74.4% accuracy for 20-way one-shot learning
# === Training loop 86 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.7899
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 71.2% accuracy for 20-way one-shot learning
# === Training loop 87 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.7690
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 67.2% accuracy for 20-way one-shot learning
# === Training loop 88 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.7446
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 18.0% accuracy for 20-way one-shot learning
# === Training loop 89 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.7590
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 34.0% accuracy for 20-way one-shot learning
# === Training loop 90 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.7403
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 44.0% accuracy for 20-way one-shot learning
# === Training loop 91 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.7318
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 70.4% accuracy for 20-way one-shot learning
# === Training loop 92 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.7214
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 64.4% accuracy for 20-way one-shot learning
# === Training loop 93 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.7597
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 67.6% accuracy for 20-way one-shot learning
# === Training loop 94 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.7158
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.4% accuracy for 20-way one-shot learning
# === Training loop 95 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.6655
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.8% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 96 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 0.6617
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.0% accuracy for 20-way one-shot learning
# === Training loop 97 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.6453
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 67.6% accuracy for 20-way one-shot learning
# === Training loop 98 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.6443
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 74.4% accuracy for 20-way one-shot learning
# === Training loop 99 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.6587
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 64.4% accuracy for 20-way one-shot learning
# === Training loop 100 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.6806
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 70.8% accuracy for 20-way one-shot learning
# === Training loop 101 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.7063
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 74.0% accuracy for 20-way one-shot learning
# === Training loop 102 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.6916
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 81.2% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 103 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.7021
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 77.6% accuracy for 20-way one-shot learning
# === Training loop 104 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.6685
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.0% accuracy for 20-way one-shot learning
# === Training loop 105 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.6684
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 71.2% accuracy for 20-way one-shot learning
# === Training loop 106 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.6305
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 75.2% accuracy for 20-way one-shot learning
# === Training loop 107 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.6300
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 57.2% accuracy for 20-way one-shot learning
# === Training loop 108 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.6561
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.0% accuracy for 20-way one-shot learning
# === Training loop 109 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.6758
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 60.4% accuracy for 20-way one-shot learning
# === Training loop 110 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 0.6637
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 52.8% accuracy for 20-way one-shot learning
# === Training loop 111 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.6438
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 70.0% accuracy for 20-way one-shot learning
# === Training loop 112 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.6507
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 75.6% accuracy for 20-way one-shot learning
# === Training loop 113 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.6584
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 70.0% accuracy for 20-way one-shot learning
# === Training loop 114 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.6076
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 54.0% accuracy for 20-way one-shot learning
# === Training loop 115 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.5955
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 54.8% accuracy for 20-way one-shot learning
# === Training loop 116 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 0.5897
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.8% accuracy for 20-way one-shot learning
# === Training loop 117 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.5916
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 75.2% accuracy for 20-way one-shot learning
# === Training loop 118 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.6016
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.4% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 119 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.6422
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 69.2% accuracy for 20-way one-shot learning
# === Training loop 120 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.6283
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.4% accuracy for 20-way one-shot learning
# === Training loop 121 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.6279
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.8% accuracy for 20-way one-shot learning
# === Training loop 122 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.6049
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 21.6% accuracy for 20-way one-shot learning
# === Training loop 123 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.6184
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 38.8% accuracy for 20-way one-shot learning
# === Training loop 124 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.6376
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 66.4% accuracy for 20-way one-shot learning
# === Training loop 125 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.6243
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 69.2% accuracy for 20-way one-shot learning
# === Training loop 126 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.5945
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 77.2% accuracy for 20-way one-shot learning
# === Training loop 127 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.5868
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.0% accuracy for 20-way one-shot learning
# === Training loop 128 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.5982
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 75.2% accuracy for 20-way one-shot learning
# === Training loop 129 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.5776
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 77.2% accuracy for 20-way one-shot learning
# === Training loop 130 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.5809
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.0% accuracy for 20-way one-shot learning
# === Training loop 131 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.6236
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 70.8% accuracy for 20-way one-shot learning
# === Training loop 132 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.6103
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.8% accuracy for 20-way one-shot learning
# === Training loop 133 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.5861
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 70.8% accuracy for 20-way one-shot learning
# === Training loop 134 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.5610
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 81.6% accuracy for 20-way one-shot learning
# === Training loop 135 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.5504
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.6% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 136 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.5335
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.8% accuracy for 20-way one-shot learning
# === Training loop 137 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.5501
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 67.6% accuracy for 20-way one-shot learning
# === Training loop 138 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.5455
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 64.4% accuracy for 20-way one-shot learning
# === Training loop 139 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.5297
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.8% accuracy for 20-way one-shot learning
# === Training loop 140 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.5309
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 77.6% accuracy for 20-way one-shot learning
# === Training loop 141 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.5140
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.8% accuracy for 20-way one-shot learning
# === Training loop 142 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.5271
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.4% accuracy for 20-way one-shot learning
# === Training loop 143 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 301ms/step - loss: 0.5576
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 73.2% accuracy for 20-way one-shot learning
# === Training loop 144 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.5396
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.4% accuracy for 20-way one-shot learning
# === Training loop 145 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.5305
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.8% accuracy for 20-way one-shot learning
# === Training loop 146 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.5459
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.8% accuracy for 20-way one-shot learning
# === Training loop 147 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.5227
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 67.2% accuracy for 20-way one-shot learning
# === Training loop 148 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.4942
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.8% accuracy for 20-way one-shot learning
# === Training loop 149 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.5153
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.4% accuracy for 20-way one-shot learning
# === Training loop 150 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.5031
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.4% accuracy for 20-way one-shot learning
# === Training loop 151 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.4980
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 44.8% accuracy for 20-way one-shot learning
# === Training loop 152 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4890
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 66.8% accuracy for 20-way one-shot learning
# === Training loop 153 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.5070
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 70.8% accuracy for 20-way one-shot learning
# === Training loop 154 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.5017
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 79.6% accuracy for 20-way one-shot learning
# === Training loop 155 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.4701
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 73.2% accuracy for 20-way one-shot learning
# === Training loop 156 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4746
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 74.8% accuracy for 20-way one-shot learning
# === Training loop 157 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.4814
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.4% accuracy for 20-way one-shot learning
# === Training loop 158 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.4634
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.0% accuracy for 20-way one-shot learning
# === Training loop 159 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4502
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 77.2% accuracy for 20-way one-shot learning
# === Training loop 160 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4497
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.8% accuracy for 20-way one-shot learning
# === Training loop 161 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4508
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 70.4% accuracy for 20-way one-shot learning
# === Training loop 162 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4638
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.2% accuracy for 20-way one-shot learning
# === Training loop 163 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4693
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 37.6% accuracy for 20-way one-shot learning
# === Training loop 164 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4749
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.8% accuracy for 20-way one-shot learning
# === Training loop 165 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4628
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 85.6% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 166 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 304ms/step - loss: 0.4677
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 74.4% accuracy for 20-way one-shot learning
# === Training loop 167 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4732
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 54.8% accuracy for 20-way one-shot learning
# === Training loop 168 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4496
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 77.6% accuracy for 20-way one-shot learning
# === Training loop 169 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4482
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.4% accuracy for 20-way one-shot learning
# === Training loop 170 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4220
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.0% accuracy for 20-way one-shot learning
# === Training loop 171 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.4220
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.4% accuracy for 20-way one-shot learning
# === Training loop 172 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4114
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.8% accuracy for 20-way one-shot learning
# === Training loop 173 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.4351
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.0% accuracy for 20-way one-shot learning
# === Training loop 174 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.4370
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 79.6% accuracy for 20-way one-shot learning
# === Training loop 175 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4452
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.0% accuracy for 20-way one-shot learning
# === Training loop 176 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4534
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.8% accuracy for 20-way one-shot learning
# === Training loop 177 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4458
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 81.2% accuracy for 20-way one-shot learning
# === Training loop 178 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4210
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 75.6% accuracy for 20-way one-shot learning
# === Training loop 179 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4145
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 79.6% accuracy for 20-way one-shot learning
# === Training loop 180 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4067
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.8% accuracy for 20-way one-shot learning
# === Training loop 181 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4243
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.4% accuracy for 20-way one-shot learning
# === Training loop 182 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4174
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.0% accuracy for 20-way one-shot learning
# === Training loop 183 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.3965
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.4% accuracy for 20-way one-shot learning
# === Training loop 184 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.3936
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.0% accuracy for 20-way one-shot learning
# === Training loop 185 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4081
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 77.6% accuracy for 20-way one-shot learning
# === Training loop 186 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4145
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.4% accuracy for 20-way one-shot learning
# === Training loop 187 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.3963
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.8% accuracy for 20-way one-shot learning
# === Training loop 188 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 301ms/step - loss: 0.3895
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.6% accuracy for 20-way one-shot learning
# === Training loop 189 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4016
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 69.6% accuracy for 20-way one-shot learning
# === Training loop 190 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.4093
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.8% accuracy for 20-way one-shot learning
# === Training loop 191 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.3940
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 81.6% accuracy for 20-way one-shot learning
# === Training loop 192 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.3890
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.4% accuracy for 20-way one-shot learning
# === Training loop 193 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.3872
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 66.4% accuracy for 20-way one-shot learning
# === Training loop 194 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 301ms/step - loss: 0.3953
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 66.4% accuracy for 20-way one-shot learning
# === Training loop 195 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.3912
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 86.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 196 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 303ms/step - loss: 0.3666
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 81.2% accuracy for 20-way one-shot learning
# === Training loop 197 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.3696
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 73.6% accuracy for 20-way one-shot learning
# === Training loop 198 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.3645
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 88.4% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 199 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 302ms/step - loss: 0.3554
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.6% accuracy for 20-way one-shot learning
# === Training loop 200 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 301ms/step - loss: 0.3847
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.8% accuracy for 20-way one-shot learning

# %%
print("The Accuracy of the siamese model is : ",best_acc, " %")
# Out:
# The Accuracy of the siamese model is :  88.4  %

# %% [markdown]
# # Siamese Model with Chi-square distance

# %%
from keras.layers import Input, Conv2D, Lambda, Dense, Flatten, MaxPooling2D, Dropout, BatchNormalization
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.losses import binary_crossentropy
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

input_shape = (105, 105, 1)
left_input = Input(input_shape)
right_input = Input(input_shape)

# build convnet to use in each siamese 'leg'
convnet = Sequential()
convnet.add(Conv2D(64, (10,10), activation='relu', input_shape=input_shape, kernel_regularizer=l2(2e-4)))
convnet.add(MaxPooling2D())
convnet.add(BatchNormalization())
convnet.add(Dropout(0.25))
convnet.add(Conv2D(128, (7,7), activation='relu', kernel_regularizer=l2(2e-4)))
convnet.add(MaxPooling2D())
convnet.add(BatchNormalization())
convnet.add(Dropout(0.25))
convnet.add(Conv2D(128, (4,4), activation='relu', kernel_regularizer=l2(2e-4)))
convnet.add(MaxPooling2D())
convnet.add(BatchNormalization())
convnet.add(Dropout(0.25))
convnet.add(Conv2D(256, (4,4), activation='relu', kernel_regularizer=l2(2e-4)))
convnet.add(Flatten())
convnet.add(BatchNormalization())
convnet.add(Dropout(0.25))
convnet.add(Dense(4096, activation="sigmoid", kernel_regularizer=l2(1e-3)))
convnet.summary()

# encode each of the two inputs into a vector with the convnet
encoded_l = convnet(left_input)
encoded_r = convnet(right_input)

# merge two encoded inputs with the chi-square distance between them, and connect to prediction output layer
L1_distance = lambda x: K.square(K.abs(x[0]-x[1]))/(x[0]+x[1])
both = Lambda(L1_distance)([encoded_l, encoded_r])
prediction = Dense(1, activation='sigmoid')(both)
siamese_net = Model(inputs=[left_input,right_input], outputs=prediction)


siamese_net.compile(loss="binary_crossentropy", optimizer="adam")

siamese_net.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 96, 96, 64)        6464
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 48, 48, 64)        0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 48, 48, 64)        256
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 42, 42, 128)       401536
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 21, 21, 128)       0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 21, 21, 128)       512
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 21, 21, 128)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 18, 18, 128)       262272
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 9, 9, 128)         0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 9, 9, 128)         512
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 9, 9, 128)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 6, 6, 256)         524544
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 9216)              36864
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 9216)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 4096)              37752832
# =================================================================
# Total params: 38,985,792
# Trainable params: 38,966,720
# Non-trainable params: 19,072
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, 105, 105, 1)  0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           (None, 105, 105, 1)  0
# __________________________________________________________________________________________________
# sequential_5 (Sequential)       (None, 4096)         38985792    input_9[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 4096)         0           sequential_5[1][0]
#                                                                  sequential_5[2][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            4097        lambda_5[0][0]
# ==================================================================================================
# Total params: 38,989,889
# Trainable params: 38,970,817
# Non-trainable params: 19,072
# __________________________________________________________________________________________________

# %%
loops = 200
best_acc = 0
for i in range(loops):
    print("=== Training loop {} ===".format(i+1))
    train(siamese_net, X_train)
    test_acc = test_oneshot(siamese_net, X_test, c_test)
    if test_acc >= best_acc:
        print("New best one-shot accuracy, saving model ...")
        siamese_net.save("/content/gdrive/My Drive/Colab Notebooks/Omniglot_all/siamese_omniglot_chisquare.h5")
        best_acc = test_acc
# Out:
# === Training loop 1 ===
# Epoch 1/1
# 100/100 [==============================] - 40s 400ms/step - loss: 3.7505
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 20.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 2 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 299ms/step - loss: 1.5195
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 18.8% accuracy for 20-way one-shot learning
# === Training loop 3 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 1.0662
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 35.6% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 4 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 299ms/step - loss: 1.0593
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 37.6% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 5 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 1.0566
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 34.4% accuracy for 20-way one-shot learning
# === Training loop 6 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 1.0604
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 27.2% accuracy for 20-way one-shot learning
# === Training loop 7 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 1.0760
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 46.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 8 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 1.1053
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 24.4% accuracy for 20-way one-shot learning
# === Training loop 9 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 1.1026
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 46.4% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 10 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 299ms/step - loss: 1.0678
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 40.4% accuracy for 20-way one-shot learning
# === Training loop 11 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 1.0948
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 37.6% accuracy for 20-way one-shot learning
# === Training loop 12 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 1.1064
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 46.8% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 13 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 299ms/step - loss: 1.0534
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 42.8% accuracy for 20-way one-shot learning
# === Training loop 14 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 1.0720
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 45.2% accuracy for 20-way one-shot learning
# === Training loop 15 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 1.0409
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 45.2% accuracy for 20-way one-shot learning
# === Training loop 16 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 1.0113
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 39.6% accuracy for 20-way one-shot learning
# === Training loop 17 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 1.0296
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 42.8% accuracy for 20-way one-shot learning
# === Training loop 18 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 1.0460
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 41.2% accuracy for 20-way one-shot learning
# === Training loop 19 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 1.0087
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 52.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 20 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 1.0309
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 51.2% accuracy for 20-way one-shot learning
# === Training loop 21 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 1.0215
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 45.6% accuracy for 20-way one-shot learning
# === Training loop 22 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.9743
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 51.2% accuracy for 20-way one-shot learning
# === Training loop 23 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.9872
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 55.2% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 24 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 300ms/step - loss: 0.9599
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 55.6% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 25 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 0.9369
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 55.2% accuracy for 20-way one-shot learning
# === Training loop 26 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 0.9359
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 52.8% accuracy for 20-way one-shot learning
# === Training loop 27 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.9331
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 55.6% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 28 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 299ms/step - loss: 0.8927
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 63.2% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 29 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 0.9044
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 58.0% accuracy for 20-way one-shot learning
# === Training loop 30 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.8763
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 56.0% accuracy for 20-way one-shot learning
# === Training loop 31 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.8479
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 60.0% accuracy for 20-way one-shot learning
# === Training loop 32 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.8584
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 58.0% accuracy for 20-way one-shot learning
# === Training loop 33 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.8760
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 59.2% accuracy for 20-way one-shot learning
# === Training loop 34 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.8278
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 60.0% accuracy for 20-way one-shot learning
# === Training loop 35 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.8290
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 57.6% accuracy for 20-way one-shot learning
# === Training loop 36 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.8202
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 59.6% accuracy for 20-way one-shot learning
# === Training loop 37 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.8261
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 61.6% accuracy for 20-way one-shot learning
# === Training loop 38 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.7954
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 58.4% accuracy for 20-way one-shot learning
# === Training loop 39 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.8061
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 55.6% accuracy for 20-way one-shot learning
# === Training loop 40 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.7736
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 71.2% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 41 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.7577
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 65.6% accuracy for 20-way one-shot learning
# === Training loop 42 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 0.7260
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 63.2% accuracy for 20-way one-shot learning
# === Training loop 43 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.7100
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 54.8% accuracy for 20-way one-shot learning
# === Training loop 44 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.7293
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 62.4% accuracy for 20-way one-shot learning
# === Training loop 45 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.6940
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 53.2% accuracy for 20-way one-shot learning
# === Training loop 46 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.6983
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 64.4% accuracy for 20-way one-shot learning
# === Training loop 47 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.6823
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 62.8% accuracy for 20-way one-shot learning
# === Training loop 48 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.6544
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 65.6% accuracy for 20-way one-shot learning
# === Training loop 49 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.6449
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 65.2% accuracy for 20-way one-shot learning
# === Training loop 50 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.6334
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 70.0% accuracy for 20-way one-shot learning
# === Training loop 51 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.6244
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 68.4% accuracy for 20-way one-shot learning
# === Training loop 52 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.5889
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 63.2% accuracy for 20-way one-shot learning
# === Training loop 53 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.5839
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.4% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 54 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 0.5967
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 68.4% accuracy for 20-way one-shot learning
# === Training loop 55 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.5803
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 64.8% accuracy for 20-way one-shot learning
# === Training loop 56 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.5685
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 46.4% accuracy for 20-way one-shot learning
# === Training loop 57 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.5670
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 58.4% accuracy for 20-way one-shot learning
# === Training loop 58 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.5602
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 75.6% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 59 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 0.5366
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 75.2% accuracy for 20-way one-shot learning
# === Training loop 60 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.5413
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 66.4% accuracy for 20-way one-shot learning
# === Training loop 61 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.5355
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 66.8% accuracy for 20-way one-shot learning
# === Training loop 62 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.5163
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 42.8% accuracy for 20-way one-shot learning
# === Training loop 63 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.5327
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.4% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 64 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 0.5426
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 71.2% accuracy for 20-way one-shot learning
# === Training loop 65 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.5091
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 58.4% accuracy for 20-way one-shot learning
# === Training loop 66 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.5255
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 73.6% accuracy for 20-way one-shot learning
# === Training loop 67 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.5030
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 40.8% accuracy for 20-way one-shot learning
# === Training loop 68 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.4830
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 70.0% accuracy for 20-way one-shot learning
# === Training loop 69 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.4736
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.0% accuracy for 20-way one-shot learning
# === Training loop 70 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.4887
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.8% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 71 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 0.4521
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 71.6% accuracy for 20-way one-shot learning
# === Training loop 72 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.4420
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 73 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 299ms/step - loss: 0.4537
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 71.6% accuracy for 20-way one-shot learning
# === Training loop 74 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.4678
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 75.2% accuracy for 20-way one-shot learning
# === Training loop 75 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.4541
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 64.8% accuracy for 20-way one-shot learning
# === Training loop 76 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.4474
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.6% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 77 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.4412
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 46.8% accuracy for 20-way one-shot learning
# === Training loop 78 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.4331
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 74.8% accuracy for 20-way one-shot learning
# === Training loop 79 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.4456
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 75.6% accuracy for 20-way one-shot learning
# === Training loop 80 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.4561
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 68.0% accuracy for 20-way one-shot learning
# === Training loop 81 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.4558
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 81.2% accuracy for 20-way one-shot learning
# === Training loop 82 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.4419
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.0% accuracy for 20-way one-shot learning
# === Training loop 83 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.4204
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 73.2% accuracy for 20-way one-shot learning
# === Training loop 84 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.4190
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.4% accuracy for 20-way one-shot learning
# === Training loop 85 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.4245
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 64.8% accuracy for 20-way one-shot learning
# === Training loop 86 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.4142
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.0% accuracy for 20-way one-shot learning
# === Training loop 87 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3841
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.8% accuracy for 20-way one-shot learning
# === Training loop 88 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3932
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.0% accuracy for 20-way one-shot learning
# === Training loop 89 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.4035
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.8% accuracy for 20-way one-shot learning
# === Training loop 90 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3893
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 81.6% accuracy for 20-way one-shot learning
# === Training loop 91 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3871
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.8% accuracy for 20-way one-shot learning
# === Training loop 92 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3802
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.0% accuracy for 20-way one-shot learning
# === Training loop 93 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3722
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.4% accuracy for 20-way one-shot learning
# === Training loop 94 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3916
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 74.4% accuracy for 20-way one-shot learning
# === Training loop 95 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3913
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 77.2% accuracy for 20-way one-shot learning
# === Training loop 96 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.3839
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 79.2% accuracy for 20-way one-shot learning
# === Training loop 97 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.3621
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.2% accuracy for 20-way one-shot learning
# === Training loop 98 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3717
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.8% accuracy for 20-way one-shot learning
# === Training loop 99 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3936
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.4% accuracy for 20-way one-shot learning
# === Training loop 100 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3719
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 71.2% accuracy for 20-way one-shot learning
# === Training loop 101 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.3578
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.4% accuracy for 20-way one-shot learning
# === Training loop 102 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3542
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 55.6% accuracy for 20-way one-shot learning
# === Training loop 103 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3387
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.8% accuracy for 20-way one-shot learning
# === Training loop 104 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3488
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.0% accuracy for 20-way one-shot learning
# === Training loop 105 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3539
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 81.6% accuracy for 20-way one-shot learning
# === Training loop 106 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3507
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.4% accuracy for 20-way one-shot learning
# === Training loop 107 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3408
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 74.4% accuracy for 20-way one-shot learning
# === Training loop 108 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3548
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 79.6% accuracy for 20-way one-shot learning
# === Training loop 109 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3456
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 81.6% accuracy for 20-way one-shot learning
# === Training loop 110 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.3426
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.0% accuracy for 20-way one-shot learning
# === Training loop 111 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3327
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.8% accuracy for 20-way one-shot learning
# === Training loop 112 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3242
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 81.2% accuracy for 20-way one-shot learning
# === Training loop 113 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3604
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.4% accuracy for 20-way one-shot learning
# === Training loop 114 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3365
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.4% accuracy for 20-way one-shot learning
# === Training loop 115 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3404
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 87.2% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 116 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 0.3385
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.4% accuracy for 20-way one-shot learning
# === Training loop 117 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.3357
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.4% accuracy for 20-way one-shot learning
# === Training loop 118 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3480
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 73.6% accuracy for 20-way one-shot learning
# === Training loop 119 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3514
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 86.4% accuracy for 20-way one-shot learning
# === Training loop 120 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.3297
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.6% accuracy for 20-way one-shot learning
# === Training loop 121 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3271
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.4% accuracy for 20-way one-shot learning
# === Training loop 122 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3291
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 77.2% accuracy for 20-way one-shot learning
# === Training loop 123 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3237
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.4% accuracy for 20-way one-shot learning
# === Training loop 124 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.3328
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.0% accuracy for 20-way one-shot learning
# === Training loop 125 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3381
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.8% accuracy for 20-way one-shot learning
# === Training loop 126 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.3297
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.4% accuracy for 20-way one-shot learning
# === Training loop 127 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3294
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.0% accuracy for 20-way one-shot learning
# === Training loop 128 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.3225
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 86.0% accuracy for 20-way one-shot learning
# === Training loop 129 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3064
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 81.2% accuracy for 20-way one-shot learning
# === Training loop 130 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3170
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 85.2% accuracy for 20-way one-shot learning
# === Training loop 131 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.3206
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 72.4% accuracy for 20-way one-shot learning
# === Training loop 132 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.3352
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.8% accuracy for 20-way one-shot learning
# === Training loop 133 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.3287
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.8% accuracy for 20-way one-shot learning
# === Training loop 134 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.3470
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 73.2% accuracy for 20-way one-shot learning
# === Training loop 135 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3310
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.2% accuracy for 20-way one-shot learning
# === Training loop 136 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.3202
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.4% accuracy for 20-way one-shot learning
# === Training loop 137 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3134
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 79.6% accuracy for 20-way one-shot learning
# === Training loop 138 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3013
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.0% accuracy for 20-way one-shot learning
# === Training loop 139 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3044
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 90.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 140 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 298ms/step - loss: 0.2990
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 86.4% accuracy for 20-way one-shot learning
# === Training loop 141 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 297ms/step - loss: 0.2962
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.0% accuracy for 20-way one-shot learning
# === Training loop 142 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3144
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 54.4% accuracy for 20-way one-shot learning
# === Training loop 143 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3226
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.2% accuracy for 20-way one-shot learning
# === Training loop 144 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3104
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 81.6% accuracy for 20-way one-shot learning
# === Training loop 145 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3133
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 87.2% accuracy for 20-way one-shot learning
# === Training loop 146 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3024
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 86.0% accuracy for 20-way one-shot learning
# === Training loop 147 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2977
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 87.6% accuracy for 20-way one-shot learning
# === Training loop 148 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.2932
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.8% accuracy for 20-way one-shot learning
# === Training loop 149 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3002
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 85.6% accuracy for 20-way one-shot learning
# === Training loop 150 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2969
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.6% accuracy for 20-way one-shot learning
# === Training loop 151 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3082
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 81.6% accuracy for 20-way one-shot learning
# === Training loop 152 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3050
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 85.6% accuracy for 20-way one-shot learning
# === Training loop 153 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.3066
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.2% accuracy for 20-way one-shot learning
# === Training loop 154 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.3039
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 88.8% accuracy for 20-way one-shot learning
# === Training loop 155 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2952
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 77.6% accuracy for 20-way one-shot learning
# === Training loop 156 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.3011
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.0% accuracy for 20-way one-shot learning
# === Training loop 157 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.3023
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 87.2% accuracy for 20-way one-shot learning
# === Training loop 158 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2865
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.4% accuracy for 20-way one-shot learning
# === Training loop 159 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2858
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.2% accuracy for 20-way one-shot learning
# === Training loop 160 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2867
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.4% accuracy for 20-way one-shot learning
# === Training loop 161 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2937
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 79.6% accuracy for 20-way one-shot learning
# === Training loop 162 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.2864
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 73.2% accuracy for 20-way one-shot learning
# === Training loop 163 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2943
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 81.6% accuracy for 20-way one-shot learning
# === Training loop 164 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2913
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.4% accuracy for 20-way one-shot learning
# === Training loop 165 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2920
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.4% accuracy for 20-way one-shot learning
# === Training loop 166 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2883
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.8% accuracy for 20-way one-shot learning
# === Training loop 167 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2904
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 71.2% accuracy for 20-way one-shot learning
# === Training loop 168 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.2961
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.6% accuracy for 20-way one-shot learning
# === Training loop 169 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 295ms/step - loss: 0.2934
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.4% accuracy for 20-way one-shot learning
# === Training loop 170 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 294ms/step - loss: 0.2921
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 69.2% accuracy for 20-way one-shot learning
# === Training loop 171 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 295ms/step - loss: 0.2877
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.6% accuracy for 20-way one-shot learning
# === Training loop 172 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 294ms/step - loss: 0.2928
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 86.4% accuracy for 20-way one-shot learning
# === Training loop 173 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.3009
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 85.2% accuracy for 20-way one-shot learning
# === Training loop 174 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 295ms/step - loss: 0.3006
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 78.8% accuracy for 20-way one-shot learning
# === Training loop 175 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 295ms/step - loss: 0.2845
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 85.6% accuracy for 20-way one-shot learning
# === Training loop 176 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.2749
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 87.2% accuracy for 20-way one-shot learning
# === Training loop 177 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 295ms/step - loss: 0.2788
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.6% accuracy for 20-way one-shot learning
# === Training loop 178 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 294ms/step - loss: 0.2838
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 79.2% accuracy for 20-way one-shot learning
# === Training loop 179 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 295ms/step - loss: 0.2755
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 87.2% accuracy for 20-way one-shot learning
# === Training loop 180 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.2806
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 80.4% accuracy for 20-way one-shot learning
# === Training loop 181 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.2852
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.2% accuracy for 20-way one-shot learning
# === Training loop 182 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 295ms/step - loss: 0.3014
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 87.6% accuracy for 20-way one-shot learning
# === Training loop 183 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.2783
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 85.2% accuracy for 20-way one-shot learning
# === Training loop 184 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2848
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 86.8% accuracy for 20-way one-shot learning
# === Training loop 185 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.2884
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 88.8% accuracy for 20-way one-shot learning
# === Training loop 186 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 295ms/step - loss: 0.2852
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 88.0% accuracy for 20-way one-shot learning
# === Training loop 187 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 295ms/step - loss: 0.2826
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.8% accuracy for 20-way one-shot learning
# === Training loop 188 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.2779
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.0% accuracy for 20-way one-shot learning
# === Training loop 189 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 295ms/step - loss: 0.2720
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 84.8% accuracy for 20-way one-shot learning
# === Training loop 190 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2662
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 56.4% accuracy for 20-way one-shot learning
# === Training loop 191 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.2750
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.4% accuracy for 20-way one-shot learning
# === Training loop 192 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 296ms/step - loss: 0.2715
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 82.8% accuracy for 20-way one-shot learning
# === Training loop 193 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 295ms/step - loss: 0.2763
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 77.2% accuracy for 20-way one-shot learning
# === Training loop 194 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.2717
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 86.4% accuracy for 20-way one-shot learning
# === Training loop 195 ===
# Epoch 1/1
# 100/100 [==============================] - 30s 295ms/step - loss: 0.2650
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 87.2% accuracy for 20-way one-shot learning
# === Training loop 196 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 295ms/step - loss: 0.2715
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 76.4% accuracy for 20-way one-shot learning
# === Training loop 197 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 294ms/step - loss: 0.2672
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.2% accuracy for 20-way one-shot learning
# === Training loop 198 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 294ms/step - loss: 0.2574
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 83.2% accuracy for 20-way one-shot learning
# === Training loop 199 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 294ms/step - loss: 0.2679
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 79.6% accuracy for 20-way one-shot learning
# === Training loop 200 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 295ms/step - loss: 0.2757
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 86.0% accuracy for 20-way one-shot learning

# %%
print("The Accuracy of the siamese model with chi-square distance is : ",best_acc, " %")
# Out:
# The Accuracy of the siamese model with chi-square distance is :  90.0  %

# %% [markdown]
# # Siamese Model with Transfer Learning

# %% [markdown]
# ###Training on MNIST

# %%
import tensorflow as tf
(x_train_original, y_train), (x_test_original, y_test) = tf.keras.datasets.mnist.load_data()

# Reshaping the array to 4-dims so that it can work with the Keras API
x_train_original = x_train_original.reshape(x_train_original.shape[0], 28, 28, 1)
x_test_original = x_test_original.reshape(x_test_original.shape[0], 28, 28, 1)

# %%
x_train = tf.image.resize_images(x_train_original, [105,105])
x_test = tf.image.resize_images(x_test_original, [105,105])

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 105, 105, 1)
# (10000, 105, 105, 1)

# %%
sess = tf.Session()
with sess.as_default():
    x_train = x_train.eval()
    x_test = x_test.eval()

# %%
# Making sure that the values are float so that we can get decimal points after division
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
# Normalizing the RGB codes by dividing it to the max RGB value.
x_train /= 255
x_test /= 255

# %%
from keras.layers import Input, Conv2D, Lambda, Dense, Flatten, MaxPooling2D, Dropout, BatchNormalization
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.losses import binary_crossentropy
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

# %%
input_shape = (105, 105, 1)

convnet = Sequential()
convnet.add(Conv2D(64, (10,10), activation='relu', input_shape=input_shape, kernel_regularizer=l2(2e-4)))
convnet.add(MaxPooling2D())
convnet.add(BatchNormalization())
convnet.add(Dropout(0.25))
convnet.add(Conv2D(128, (7,7), activation='relu', kernel_regularizer=l2(2e-4)))
convnet.add(MaxPooling2D())
convnet.add(BatchNormalization())
convnet.add(Dropout(0.25))
convnet.add(Conv2D(128, (4,4), activation='relu', kernel_regularizer=l2(2e-4)))
convnet.add(MaxPooling2D())
convnet.add(BatchNormalization())
convnet.add(Dropout(0.25))
convnet.add(Conv2D(256, (4,4), activation='relu', kernel_regularizer=l2(2e-4)))
convnet.add(Flatten())
convnet.add(BatchNormalization())
convnet.add(Dropout(0.25))
convnet.add(Dense(4096, activation="sigmoid", kernel_regularizer=l2(1e-3)))
convnet.add(Dropout(0.2))
convnet.add(Dense(10,activation=tf.nn.softmax))
convnet.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 96, 96, 64)        6464
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 42, 42, 128)       401536
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 21, 21, 128)       0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 21, 21, 128)       512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 21, 21, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 18, 18, 128)       262272
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 9, 9, 128)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 9, 9, 128)         512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 9, 9, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 6, 6, 256)         524544
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 9216)              36864
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 9216)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              37752832
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 39,026,762
# Trainable params: 39,007,690
# Non-trainable params: 19,072
# _________________________________________________________________

# %%
convnet.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])
convnet.fit(x=x_train,y=y_train, epochs=10)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 254s 4ms/step - loss: 1.7984 - acc: 0.9348
# Epoch 2/10
# 60000/60000 [==============================] - 247s 4ms/step - loss: 1.5811 - acc: 0.9528
# Epoch 3/10
# 60000/60000 [==============================] - 246s 4ms/step - loss: 1.6122 - acc: 0.9567
# Epoch 4/10
# 60000/60000 [==============================] - 247s 4ms/step - loss: 1.5606 - acc: 0.9598
# Epoch 5/10
# 60000/60000 [==============================] - 247s 4ms/step - loss: 1.4686 - acc: 0.9626
# Epoch 6/10
# 60000/60000 [==============================] - 247s 4ms/step - loss: 1.3251 - acc: 0.9653
# Epoch 7/10
# 60000/60000 [==============================] - 247s 4ms/step - loss: 1.2132 - acc: 0.9671
# Epoch 8/10
# 60000/60000 [==============================] - 248s 4ms/step - loss: 1.0532 - acc: 0.9687
# Epoch 9/10
# 60000/60000 [==============================] - 247s 4ms/step - loss: 0.8844 - acc: 0.9713
# Epoch 10/10
# 60000/60000 [==============================] - 247s 4ms/step - loss: 0.7472 - acc: 0.9733

# %%
convnet.evaluate(x_test, y_test)
# Out:
# 10000/10000 [==============================] - 10s 1ms/step
# [0.6254367026329041, 0.9814]

# %%
convnet.save('/content/gdrive/My Drive/Colab Notebooks/Saved Models/mnist_siamese.h5')

# %% [markdown]
# ### Making saimese network

# %%
from keras.models import Model
from keras.models import load_model

input_shape = (105, 105, 1)
left_input = Input(input_shape)
right_input = Input(input_shape)

transfer_model = Sequential()
model = load_model('/content/gdrive/My Drive/Colab Notebooks/Saved Models/mnist_siamese.h5')

for layer in model.layers[:-5]:  #ignore last 5 layers
    transfer_model.add(layer)

for layer in transfer_model.layers:  #Old layers are set to non-trainable
    layer.trainable = False

#transfer_model=Model(inputs=transfer_model.input,outputs=preds)
transfer_model.add(BatchNormalization())
transfer_model.add(Dropout(0.25))
transfer_model.add(Dense(8192, activation="sigmoid", kernel_regularizer=l2(1e-3)))
transfer_model.add(Dense(4096, activation="sigmoid", kernel_regularizer=l2(1e-3)))
transfer_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 96, 96, 64)        6464
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 42, 42, 128)       401536
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 21, 21, 128)       0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 21, 21, 128)       512
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 21, 21, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 18, 18, 128)       262272
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 9, 9, 128)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 9, 9, 128)         512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 9, 9, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 6, 6, 256)         524544
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9216)              36864
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9216)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 8192)              75505664
# _________________________________________________________________
# dense_6 (Dense)              (None, 4096)              33558528
# =================================================================
# Total params: 110,297,152
# Trainable params: 109,082,624
# Non-trainable params: 1,214,528
# _________________________________________________________________

# %%
# encode each of the two inputs into a vector with the convnet
encoded_l = transfer_model(left_input)
encoded_r = transfer_model(right_input)

# merge two encoded inputs with the L1 distance between them, and connect to prediction output layer
L1_distance = lambda x: K.abs(x[0]-x[1])
both = Lambda(L1_distance)([encoded_l, encoded_r])
prediction = Dense(1, activation='sigmoid')(both)
siamese_net = Model(inputs=[left_input,right_input], outputs=prediction)


siamese_net.compile(loss="binary_crossentropy", optimizer="adam")

siamese_net.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 105, 105, 1)  0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 105, 105, 1)  0
# __________________________________________________________________________________________________
# sequential_3 (Sequential)       (None, 4096)         110297152   input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 4096)         0           sequential_3[1][0]
#                                                                  sequential_3[2][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            4097        lambda_2[0][0]
# ==================================================================================================
# Total params: 110,301,249
# Trainable params: 109,086,721
# Non-trainable params: 1,214,528
# __________________________________________________________________________________________________

# %%
#get omniglot input
PATH = '/content/gdrive/My Drive/Colab Notebooks/Omniglot_all/pickle_files/'

with open(os.path.join(PATH, "omniglot_train.p"), "rb") as f:
    (X_train, c_train) = pickle.load(f)

with open(os.path.join(PATH, "omniglot_test.p"), "rb") as f:
    (X_test, c_test) = pickle.load(f)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("")
print("training alphabets")
print([key for key in c_train.keys()])
print("test alphabets:")
print([key for key in c_test.keys()])
# Out:
# X_train shape: (964, 20, 105, 105)
# X_test shape: (659, 20, 105, 105)
#
# training alphabets
# ['Arcadian', 'Burmese_(Myanmar)', 'Balinese', 'Blackfoot_(Canadian_Aboriginal_Syllabics)', 'Braille', 'Armenian', 'Anglo-Saxon_Futhorc', 'Alphabet_of_the_Magi', 'Asomtavruli_(Georgian)', 'Bengali', 'Hebrew', 'Japanese_(katakana)', 'Gujarati', 'Grantha', 'Futurama', 'Inuktitut_(Canadian_Aboriginal_Syllabics)', 'Japanese_(hiragana)', 'Early_Aramaic', 'Greek', 'Cyrillic', 'Malay_(Jawi_-_Arabic)', 'N_Ko', 'Tagalog', 'Latin', 'Tifinagh', 'Syriac_(Estrangelo)', 'Korean', 'Mkhedruli_(Georgian)', 'Sanskrit', 'Ojibwe_(Canadian_Aboriginal_Syllabics)']
# test alphabets:
# ['Keble', 'Atlantean', 'Angelic', 'Avesta', 'Ge_ez', 'Atemayar_Qelisayer', 'Aurek-Besh', 'Kannada', 'Gurmukhi', 'Glagolitic', 'Tibetan', 'Mongolian', 'Malayalam', 'Manipuri', 'Oriya', 'Tengwar', 'Sylheti', 'Syriac_(Serto)', 'ULOG', 'Old_Church_Slavonic_(Cyrillic)']

# %%
loops = 200
best_acc = 0
for i in range(loops):
    print("=== Training loop {} ===".format(i+1))
    train(siamese_net, X_train)
    test_acc = test_oneshot(siamese_net, X_test, c_test)
    if test_acc >= best_acc:
        print("New best one-shot accuracy, saving model ...")
        siamese_net.save("/content/gdrive/My Drive/Colab Notebooks/Omniglot_all/siamese_omniglot_transfer.h5")
        best_acc = test_acc
# Out:
# === Training loop 1 ===
# Epoch 1/1
# 100/100 [==============================] - 40s 398ms/step - loss: 3.9419
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 12.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 2 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 1.0976
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 6.4% accuracy for 20-way one-shot learning
# === Training loop 3 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0316
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 4.0% accuracy for 20-way one-shot learning
# === Training loop 4 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0244
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 5.2% accuracy for 20-way one-shot learning
# === Training loop 5 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0121
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 15.2% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 6 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9810
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 16.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 7 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 291ms/step - loss: 0.9744
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 17.6% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 8 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 291ms/step - loss: 0.9855
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 9 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 0.9634
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 23.2% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 10 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 0.9508
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 17.2% accuracy for 20-way one-shot learning
# === Training loop 11 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9727
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 16.0% accuracy for 20-way one-shot learning
# === Training loop 12 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9908
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 23.2% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 13 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 0.9706
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 21.6% accuracy for 20-way one-shot learning
# === Training loop 14 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.9808
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.8% accuracy for 20-way one-shot learning
# === Training loop 15 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9958
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 23.6% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 16 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 0.9969
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.4% accuracy for 20-way one-shot learning
# === Training loop 17 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0163
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 18.8% accuracy for 20-way one-shot learning
# === Training loop 18 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0339
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 18.4% accuracy for 20-way one-shot learning
# === Training loop 19 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0425
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 16.4% accuracy for 20-way one-shot learning
# === Training loop 20 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0504
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 17.2% accuracy for 20-way one-shot learning
# === Training loop 21 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0480
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 16.0% accuracy for 20-way one-shot learning
# === Training loop 22 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 1.0439
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 18.4% accuracy for 20-way one-shot learning
# === Training loop 23 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0586
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 18.4% accuracy for 20-way one-shot learning
# === Training loop 24 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0543
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 20.4% accuracy for 20-way one-shot learning
# === Training loop 25 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0497
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 18.4% accuracy for 20-way one-shot learning
# === Training loop 26 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 1.0821
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.0% accuracy for 20-way one-shot learning
# === Training loop 27 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0583
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 20.0% accuracy for 20-way one-shot learning
# === Training loop 28 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0800
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 17.2% accuracy for 20-way one-shot learning
# === Training loop 29 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0776
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 24.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 30 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 291ms/step - loss: 1.0804
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 17.2% accuracy for 20-way one-shot learning
# === Training loop 31 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0823
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 16.8% accuracy for 20-way one-shot learning
# === Training loop 32 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0633
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 16.4% accuracy for 20-way one-shot learning
# === Training loop 33 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0984
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 20.8% accuracy for 20-way one-shot learning
# === Training loop 34 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0926
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.8% accuracy for 20-way one-shot learning
# === Training loop 35 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 287ms/step - loss: 1.0912
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.0% accuracy for 20-way one-shot learning
# === Training loop 36 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0816
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 18.8% accuracy for 20-way one-shot learning
# === Training loop 37 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0792
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 19.2% accuracy for 20-way one-shot learning
# === Training loop 38 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0920
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.4% accuracy for 20-way one-shot learning
# === Training loop 39 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.1037
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 17.6% accuracy for 20-way one-shot learning
# === Training loop 40 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.1145
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 20.4% accuracy for 20-way one-shot learning
# === Training loop 41 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0889
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 25.6% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 42 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 1.0919
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.0% accuracy for 20-way one-shot learning
# === Training loop 43 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.1265
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 20.0% accuracy for 20-way one-shot learning
# === Training loop 44 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.1085
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.4% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 45 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 1.0976
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 23.6% accuracy for 20-way one-shot learning
# === Training loop 46 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.1274
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 23.2% accuracy for 20-way one-shot learning
# === Training loop 47 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.1320
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 18.8% accuracy for 20-way one-shot learning
# === Training loop 48 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.1009
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 19.2% accuracy for 20-way one-shot learning
# === Training loop 49 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.1055
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 18.8% accuracy for 20-way one-shot learning
# === Training loop 50 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0899
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.0% accuracy for 20-way one-shot learning
# === Training loop 51 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0817
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 17.6% accuracy for 20-way one-shot learning
# === Training loop 52 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.1221
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.0% accuracy for 20-way one-shot learning
# === Training loop 53 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0790
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 25.2% accuracy for 20-way one-shot learning
# === Training loop 54 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0979
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 18.4% accuracy for 20-way one-shot learning
# === Training loop 55 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0738
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 21.6% accuracy for 20-way one-shot learning
# === Training loop 56 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.1015
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.8% accuracy for 20-way one-shot learning
# === Training loop 57 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0785
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 24.0% accuracy for 20-way one-shot learning
# === Training loop 58 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0900
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 25.2% accuracy for 20-way one-shot learning
# === Training loop 59 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0914
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 24.0% accuracy for 20-way one-shot learning
# === Training loop 60 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0947
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 21.6% accuracy for 20-way one-shot learning
# === Training loop 61 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.1108
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 20.0% accuracy for 20-way one-shot learning
# === Training loop 62 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.1157
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 21.6% accuracy for 20-way one-shot learning
# === Training loop 63 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.1030
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 25.6% accuracy for 20-way one-shot learning
# === Training loop 64 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0970
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 32.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 65 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 1.0575
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 31.2% accuracy for 20-way one-shot learning
# === Training loop 66 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0841
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.0% accuracy for 20-way one-shot learning
# === Training loop 67 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0693
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 25.6% accuracy for 20-way one-shot learning
# === Training loop 68 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0848
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 19.6% accuracy for 20-way one-shot learning
# === Training loop 69 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0630
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.4% accuracy for 20-way one-shot learning
# === Training loop 70 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0788
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 23.2% accuracy for 20-way one-shot learning
# === Training loop 71 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.1178
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 21.2% accuracy for 20-way one-shot learning
# === Training loop 72 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.1026
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.8% accuracy for 20-way one-shot learning
# === Training loop 73 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0762
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 33.6% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 74 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 1.1011
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.4% accuracy for 20-way one-shot learning
# === Training loop 75 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0893
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 23.6% accuracy for 20-way one-shot learning
# === Training loop 76 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0671
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.4% accuracy for 20-way one-shot learning
# === Training loop 77 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.1120
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 29.2% accuracy for 20-way one-shot learning
# === Training loop 78 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.1017
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.8% accuracy for 20-way one-shot learning
# === Training loop 79 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0944
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.4% accuracy for 20-way one-shot learning
# === Training loop 80 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0904
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 24.4% accuracy for 20-way one-shot learning
# === Training loop 81 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0944
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.4% accuracy for 20-way one-shot learning
# === Training loop 82 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0847
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.0% accuracy for 20-way one-shot learning
# === Training loop 83 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0990
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 27.2% accuracy for 20-way one-shot learning
# === Training loop 84 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.1064
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.0% accuracy for 20-way one-shot learning
# === Training loop 85 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.1187
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 24.8% accuracy for 20-way one-shot learning
# === Training loop 86 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.1057
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.0% accuracy for 20-way one-shot learning
# === Training loop 87 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0842
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 24.0% accuracy for 20-way one-shot learning
# === Training loop 88 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0677
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 31.6% accuracy for 20-way one-shot learning
# === Training loop 89 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0678
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 25.6% accuracy for 20-way one-shot learning
# === Training loop 90 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0807
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.4% accuracy for 20-way one-shot learning
# === Training loop 91 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0686
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.8% accuracy for 20-way one-shot learning
# === Training loop 92 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0793
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 24.4% accuracy for 20-way one-shot learning
# === Training loop 93 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 1.0639
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 25.6% accuracy for 20-way one-shot learning
# === Training loop 94 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0916
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 29.2% accuracy for 20-way one-shot learning
# === Training loop 95 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 1.1054
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 32.4% accuracy for 20-way one-shot learning
# === Training loop 96 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0728
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.0% accuracy for 20-way one-shot learning
# === Training loop 97 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0622
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.0% accuracy for 20-way one-shot learning
# === Training loop 98 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0429
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.8% accuracy for 20-way one-shot learning
# === Training loop 99 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0555
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.8% accuracy for 20-way one-shot learning
# === Training loop 100 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0451
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 32.4% accuracy for 20-way one-shot learning
# === Training loop 101 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0624
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.4% accuracy for 20-way one-shot learning
# === Training loop 102 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0604
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 25.6% accuracy for 20-way one-shot learning
# === Training loop 103 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0671
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.0% accuracy for 20-way one-shot learning
# === Training loop 104 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0752
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 29.6% accuracy for 20-way one-shot learning
# === Training loop 105 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0498
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.4% accuracy for 20-way one-shot learning
# === Training loop 106 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0590
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 29.2% accuracy for 20-way one-shot learning
# === Training loop 107 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0438
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 33.2% accuracy for 20-way one-shot learning
# === Training loop 108 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0516
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 24.8% accuracy for 20-way one-shot learning
# === Training loop 109 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0296
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.4% accuracy for 20-way one-shot learning
# === Training loop 110 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.9961
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.4% accuracy for 20-way one-shot learning
# === Training loop 111 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0451
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.4% accuracy for 20-way one-shot learning
# === Training loop 112 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0398
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 27.6% accuracy for 20-way one-shot learning
# === Training loop 113 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0479
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 31.6% accuracy for 20-way one-shot learning
# === Training loop 114 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0533
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.8% accuracy for 20-way one-shot learning
# === Training loop 115 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 1.0299
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 23.6% accuracy for 20-way one-shot learning
# === Training loop 116 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0559
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 36.8% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 117 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 1.0229
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 29.2% accuracy for 20-way one-shot learning
# === Training loop 118 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0084
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 29.2% accuracy for 20-way one-shot learning
# === Training loop 119 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0245
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 24.8% accuracy for 20-way one-shot learning
# === Training loop 120 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0496
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 27.6% accuracy for 20-way one-shot learning
# === Training loop 121 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0277
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.8% accuracy for 20-way one-shot learning
# === Training loop 122 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0307
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 32.0% accuracy for 20-way one-shot learning
# === Training loop 123 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0210
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 27.6% accuracy for 20-way one-shot learning
# === Training loop 124 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9894
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 38.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 125 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 291ms/step - loss: 0.9997
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.4% accuracy for 20-way one-shot learning
# === Training loop 126 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0118
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 29.6% accuracy for 20-way one-shot learning
# === Training loop 127 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9909
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.8% accuracy for 20-way one-shot learning
# === Training loop 128 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0505
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 33.6% accuracy for 20-way one-shot learning
# === Training loop 129 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 1.0015
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.8% accuracy for 20-way one-shot learning
# === Training loop 130 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9679
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.8% accuracy for 20-way one-shot learning
# === Training loop 131 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9622
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 29.6% accuracy for 20-way one-shot learning
# === Training loop 132 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9690
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.8% accuracy for 20-way one-shot learning
# === Training loop 133 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9479
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 32.4% accuracy for 20-way one-shot learning
# === Training loop 134 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 0.9445
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.0% accuracy for 20-way one-shot learning
# === Training loop 135 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 1.0013
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 27.6% accuracy for 20-way one-shot learning
# === Training loop 136 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 0.9624
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.4% accuracy for 20-way one-shot learning
# === Training loop 137 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9467
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.0% accuracy for 20-way one-shot learning
# === Training loop 138 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9604
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.0% accuracy for 20-way one-shot learning
# === Training loop 139 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9332
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.4% accuracy for 20-way one-shot learning
# === Training loop 140 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9413
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 31.6% accuracy for 20-way one-shot learning
# === Training loop 141 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.9094
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.4% accuracy for 20-way one-shot learning
# === Training loop 142 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9119
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.4% accuracy for 20-way one-shot learning
# === Training loop 143 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9382
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.8% accuracy for 20-way one-shot learning
# === Training loop 144 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.9563
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 33.6% accuracy for 20-way one-shot learning
# === Training loop 145 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 1.0171
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 38.0% accuracy for 20-way one-shot learning
# New best one-shot accuracy, saving model ...
# === Training loop 146 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9877
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.8% accuracy for 20-way one-shot learning
# === Training loop 147 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.9444
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 33.6% accuracy for 20-way one-shot learning
# === Training loop 148 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8893
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 33.6% accuracy for 20-way one-shot learning
# === Training loop 149 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9107
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 22.4% accuracy for 20-way one-shot learning
# === Training loop 150 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8903
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 24.4% accuracy for 20-way one-shot learning
# === Training loop 151 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 0.9295
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 34.4% accuracy for 20-way one-shot learning
# === Training loop 152 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9480
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.0% accuracy for 20-way one-shot learning
# === Training loop 153 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9143
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 32.4% accuracy for 20-way one-shot learning
# === Training loop 154 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.8942
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 29.6% accuracy for 20-way one-shot learning
# === Training loop 155 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8571
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 36.8% accuracy for 20-way one-shot learning
# === Training loop 156 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9042
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 27.6% accuracy for 20-way one-shot learning
# === Training loop 157 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8784
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 24.8% accuracy for 20-way one-shot learning
# === Training loop 158 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.9047
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 25.2% accuracy for 20-way one-shot learning
# === Training loop 159 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 0.9031
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.8% accuracy for 20-way one-shot learning
# === Training loop 160 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8809
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 34.8% accuracy for 20-way one-shot learning
# === Training loop 161 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8638
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 32.8% accuracy for 20-way one-shot learning
# === Training loop 162 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8952
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 34.4% accuracy for 20-way one-shot learning
# === Training loop 163 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8674
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 29.2% accuracy for 20-way one-shot learning
# === Training loop 164 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9220
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 35.6% accuracy for 20-way one-shot learning
# === Training loop 165 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 0.8790
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 32.4% accuracy for 20-way one-shot learning
# === Training loop 166 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.9292
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 31.2% accuracy for 20-way one-shot learning
# === Training loop 167 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8716
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 29.6% accuracy for 20-way one-shot learning
# === Training loop 168 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.8748
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 29.2% accuracy for 20-way one-shot learning
# === Training loop 169 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8720
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 35.6% accuracy for 20-way one-shot learning
# === Training loop 170 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8655
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.8% accuracy for 20-way one-shot learning
# === Training loop 171 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8885
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 31.6% accuracy for 20-way one-shot learning
# === Training loop 172 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8715
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.0% accuracy for 20-way one-shot learning
# === Training loop 173 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.8569
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.8% accuracy for 20-way one-shot learning
# === Training loop 174 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8602
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.4% accuracy for 20-way one-shot learning
# === Training loop 175 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8234
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.4% accuracy for 20-way one-shot learning
# === Training loop 176 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.8583
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 33.2% accuracy for 20-way one-shot learning
# === Training loop 177 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8531
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.4% accuracy for 20-way one-shot learning
# === Training loop 178 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8198
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 27.6% accuracy for 20-way one-shot learning
# === Training loop 179 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 290ms/step - loss: 0.8347
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 31.2% accuracy for 20-way one-shot learning
# === Training loop 180 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8762
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 20.4% accuracy for 20-way one-shot learning
# === Training loop 181 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8563
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.8% accuracy for 20-way one-shot learning
# === Training loop 182 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8586
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 35.6% accuracy for 20-way one-shot learning
# === Training loop 183 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.8524
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 25.6% accuracy for 20-way one-shot learning
# === Training loop 184 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8324
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.8% accuracy for 20-way one-shot learning
# === Training loop 185 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.8659
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 28.8% accuracy for 20-way one-shot learning
# === Training loop 186 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8545
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 37.2% accuracy for 20-way one-shot learning
# === Training loop 187 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8418
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.0% accuracy for 20-way one-shot learning
# === Training loop 188 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8677
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.4% accuracy for 20-way one-shot learning
# === Training loop 189 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.8601
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 31.2% accuracy for 20-way one-shot learning
# === Training loop 190 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8474
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.4% accuracy for 20-way one-shot learning
# === Training loop 191 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8420
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 30.0% accuracy for 20-way one-shot learning
# === Training loop 192 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8269
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 32.8% accuracy for 20-way one-shot learning
# === Training loop 193 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.7982
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 32.0% accuracy for 20-way one-shot learning
# === Training loop 194 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.7967
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.8% accuracy for 20-way one-shot learning
# === Training loop 195 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.7972
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 31.2% accuracy for 20-way one-shot learning
# === Training loop 196 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.7981
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 32.0% accuracy for 20-way one-shot learning
# === Training loop 197 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.8722
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 32.0% accuracy for 20-way one-shot learning
# === Training loop 198 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8358
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 34.8% accuracy for 20-way one-shot learning
# === Training loop 199 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 289ms/step - loss: 0.8039
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 26.4% accuracy for 20-way one-shot learning
# === Training loop 200 ===
# Epoch 1/1
# 100/100 [==============================] - 29s 288ms/step - loss: 0.8288
# Evaluating model on 250 random 20-way one-shot learning tasks ...
# Got an average of 31.2% accuracy for 20-way one-shot learning

# %%
print("The Accuracy of the transfer siamese model is : ",best_acc, " %")
# Out:
# The Accuracy of the transfer siamese model is :  38.0  %
